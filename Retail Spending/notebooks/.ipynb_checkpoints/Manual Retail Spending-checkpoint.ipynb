# %% [markdown]
# # Predicting Retail Spending with Manual Feature Engineering
#
# In this notebook we will work with a dataset of online retail transactions. This data is originally from [the UCI Machine Learning Repository.](https://archive.ics.uci.edu/ml/datasets/online+retail#) and is a great example of real-world time-series data. Our objective will be to develop a model that can predict the spending of a customer in the next month given the past spending data for that customer. We'll approach the problem using manual feature engineering combining aggregations with domain knowledge to build a set of features for use in a modeling pipeline.
#
# As we saw in previous notebooks, the traditional approach to feature engineering is to add features one at a time based on domain knowledge. A more efficient method is to use functions combined with aggregations - an approach we called semi-automated feature engineering - which let us build multiple features at once. Here we'll stick mostly to the semi-automated method, but I encourage anyone to try out the traditional approach to see if they can surpass the performance.
#
# ## Problem
#
# In the automated feature engineering notebook, we first an example of Prediction Engineering, defining a problem that we want to predict - in this case classifying customers into those who will spend more than \$500 in the next month and those who will not - and then how to generate a set of labels for those predictions. We use each customer as a label multiple times, which allows us to create more training observations, but also means that we need to be careful to build features using only valid data.
#
# With the automated feature engineering approach using Featuretools, we didn't have to worry about using invalid data because the library takes care of the data filters for us using cutoff times. After passing the cutoff times to Featuretools, it automatically built features for us respecting the times filters. Moreover, we were able to build a set of features that significantly outperformed the baseline and were interpretable in the context of the problem. In this notebook, we'll approach the problem completely by hand, relying on our own abilities as data scientists to develop a set of valid, relevant features for the prediction problem.

# %%
# Data manipulation
import pandas as pd 
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Automated feature engineering
import featuretools as ft

# Machine learning
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer, MinMaxScaler
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# First let's load in the raw data and take a look. We'll apply the same data formatting principles as in the automated feature engineering notebook.

# %%
csv_s3 = "s3://featurelabs-static/online-retail-logs.csv"
data = pd.read_csv(csv_s3, parse_dates=["order_date"])

# Convert to dollars
data['price'] = data['price'] * 1.65
data['total'] = data['price'] * data['quantity']

# Restrict data to 2011
data = data[data['order_date'].dt.year == 2011]

# drop the duplicates
data = data.drop_duplicates()

# drop rows with null customer id
data = data.dropna(axis=0)

data.head()
# Out:
#       order_id product_id                description  quantity  \
# 42481   539993      22386    JUMBO BAG PINK POLKADOT        10
# 42482   539993      21499         BLUE POLKADOT WRAP        25
# 42483   539993      21498        RED RETROSPOT WRAP         25
# 42484   539993      22379   RECYCLING BAG RETROSPOT          5
# 42485   539993      20718  RED RETROSPOT SHOPPER BAG        10
#
#                order_date   price  customer_id         country   total
# 42481 2011-01-04 10:00:00  3.2175      13313.0  United Kingdom  32.175
# 42482 2011-01-04 10:00:00  0.6930      13313.0  United Kingdom  17.325
# 42483 2011-01-04 10:00:00  0.6930      13313.0  United Kingdom  17.325
# 42484 2011-01-04 10:00:00  3.4650      13313.0  United Kingdom  17.325
# 42485 2011-01-04 10:00:00  2.0625      13313.0  United Kingdom  20.625

# %% [markdown]
# # Load in Prediction Problem
#
# We already created the prediction problem in the automated feature engineering notebook. The objective is to predict the total spending of customers in the next month. Instead of forecasting the amount which would be a regression problem, we decided to group customers into a segment that spends more than \$500 and a segment spending less, making this a classification task.
#
# Each customer is represented in the labels multiple times, once for each month that we want to predict. Using customers multiple times allows us to construct more labelled training examples. However, it also means that we must be careful in the data we use when creating features for that specific customer in that month.

# %%
labels = pd.read_csv('../input/labels.csv', index_col=0)
labels.head()
# Out:
#    customer_id cutoff_time       total  label
# 0      12352.0  2011-03-01    502.7220      1
# 1      12383.0  2011-03-01    589.1655      1
# 2      12388.0  2011-03-01    347.9850      0
# 3      12395.0  2011-03-01    538.7250      1
# 4      12415.0  2011-03-01  27320.9310      1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['font.size'] = 18
from IPython.core.pylabtools import figsize
figsize(8, 6)

# KDE plot of total price
sns.distplot(labels['total'], hist=False, color = 'red');
plt.title('Total Spent per Month Distribution');
plt.xlabel('Total'); plt.ylabel('Density');

# %% [markdown]
# Based on the unequal distribution of totals spent per month (some of which can be negative due to cancelled orders) we decided to frame this as a classification problem. The extreme skewness of the distribution can be seen in an [empirical cumulative distribution function](https://en.wikipedia.org/wiki/Empirical_distribution_function) plot of the total spending per month.

# %%
def ecdf(a):
    x = np.sort(a)
    y = np.arange(len(x)) / float(len(x))
    return x, y

# %%
x, y = ecdf(labels['total'])
plt.plot(x, y, '.');
plt.xlabel('Total'); plt.ylabel('Percentile'); plt.title('ECDF of Total Spent per Month');
print(f'The 90th percentile is at ${round(x[np.where(y > 0.9)[0][0]], 2)}')
# Out:
# The 90th percentile is at $792.76

# %%
print(f'There are {len(data)} observations in the final data with {data["customer_id"].nunique()} unique customers.')
print(f'There are {len(labels)} labels.')
# Out:
# There are 375250 observations in the final data with 4244 unique customers.
# There are 28133 labels.

# %% [markdown]
# We are using the same exact dataset and labels as we did with automated feature engineering for comparison purposes.

# %% [markdown]
# # Feature Engineering
#
# Once we have a prediction we want to make, we need to figure out how to get the data into a format for training a model. For each label (a customer - month) we are going to need one row of data, with the columns forming the features. The tricky part is that we must be sure to not use any future data for predicting in a given month. As a first pass, we can limit ourselves to trying to build a model to make predictions for December 2011. Since this is the last month in the dataset, we should have the most data and be able to build an accurate model.
#
# Feature engineering will require us to aggregate information that is on the purchase level into information on the customer level. We need to try and create features that are relevant for predicting how much a customer will spend in the future. We can do this by incorporating domain knowledge and building features either one at a time, or in groups using multiple aggregations at once. Our final training dataframe must have one row for each customer-month where the features are made using only data from before that month.
#
# ## Enriching the data
#
# One of the simplest feature engineering steps is to extract information from the original data such as by finding the `weekday`, `month`, `hour`, and `minute` of the purchase. (These are referred to as transform primitives in Featuretools).

# %%
data['weekday'] = data['order_date'].dt.weekday
data['month'] = data['order_date'].dt.month
data['minute'] = data['order_date'].dt.minute
data['hour'] = data['order_date'].dt.hour
data['date_only'] = data['order_date'].dt.date

# Plot of purchases by day of week
data['weekday'].value_counts().sort_index().plot.bar(color = 'orange');
plt.title('Purchases by Day of Week'); plt.ylabel('Purchases'); plt.xlabel('Day of Week');

# %%
data['hour'].value_counts().sort_index().plot.bar(color = 'orange');
plt.title('Purchases by Time of Day'); plt.ylabel('Purchases'); plt.xlabel('Hour of Day');

# %%
figsize(20, 6)
trends = data.groupby('date_only')['total'].sum()
trends.plot()
plt.title('Total Purchase Amount over Time'); plt.xlabel(''); plt.ylabel('Total Purchase Amount');

# %% [markdown]
# We can't yet use these features for machine learning since they are still on a _purchase_ level. We need features on a _customer_ level.
#
# ### Subset to Valid Data
#
# Before we go any further, we are going to want to subset to the valid data. Our first goal is to predict only December spending, so for our training data, we'll limit ourselves to data before November while our testing data will use only information in November. The training labels are for customer - months from November and before, and the testing labels are those from December. For each training label, we'll build features using only the data from before the month in question. For example, if our label is from November, we'll use only data for the customer in October when building a set of features.
#
# To summarize if we are making predictions for December 2011:
#
# * Training data: from before November 2011
#     * Each training example will use only data from the month before the label
# * Testing data: data from November 2011
# * Training labels: customer - months from before December 2011
#     * Each training label covers spending by one customer in one month
# * Testing labels: customer spending in December 2011
#
# The following code subsets the data.

# %%
labels['cutoff_time'] = pd.to_datetime(labels['cutoff_time'])
labels['month'] = labels['cutoff_time'].dt.month

# %%
train = data[data['month'] < 11]
test = data[data['month'] == 11]
train_labels = labels.loc[labels['month'] < 12, ['customer_id', 'label', 'month']]
test_labels = labels.loc[labels['month'] == 12, ['customer_id', 'label', 'month']]

# %% [markdown]
# Let's quickly look at the results of an informed baseline guess for December. This guess comes from using the spending of the customer in November (the previous month) as the prediction in the next month.

# %%
def informed_baseline(month_number, threshold = 500, quiet = False):
    """Calculate an informed baseline for a given month. 
    The informed baseline is guessing the previous month's spending
    for the next month. The probability is assessed by dividing
    the previous month's total by the threshold and setting
    any values greater than 1 to 1."""
    
    # Subset to the months
    month = labels[labels['month'] == month_number]
    previous_month = labels[labels['month'] == (month_number - 1)]
    
    previous_month = previous_month.rename(columns = {'total': 'previous_total'})

    # Merge the current month with the previous month
    month = month.merge(previous_month[['customer_id', 'previous_total']], on = 'customer_id', how = 'left')
    
    month['previous_total'] = month['previous_total'].fillna(0)
    month['probability'] = month['previous_total'] / threshold
    
    # Set probabilities greater than 1 equal to 1
    month.loc[month['probability'] > 1, 'probability'] = 1
    
    # Make the predicted label
    month['prediction'] = (month['previous_total'] > threshold).astype(int)
    if not quiet:
        print('Precision: {:.5f}.'.format(precision_score(month['label'], month['prediction'])))
        print('Recall: {:.5f}.'.format(recall_score(month['label'], month['prediction'])))
        print('F1 Score: {:.5f}.'.format(f1_score(month['label'], month['prediction'])))
        print('ROC AUC Score: {:.5f}.'.format(roc_auc_score(month['label'], month['probability'])))
    
    return month

# %%
december_informed = informed_baseline(12)
# Out:
# Precision: 0.21606.
# Recall: 0.57547.
# F1 Score: 0.31416.
# ROC AUC Score: 0.69502.

# %% [markdown]
# This gives us a target to beat: if our model is not better than the informed baseline, then we are better off using the baseline instead of machine learning! In the automated feature engineering notebook, the best model was able to score __0.81378 ROC AUC__ for December, significantly better than the baseline.
#
# We will test our manual engineered features in the same way that we did for automated feature engineering in order to make comparisons. This means making predictions for one month and training on all previous months. Theoretically, model performance should be highest in December (the last month of the data) because we are using the most previous information. (This won't necessarily be the case though if customer spending habits change over time).
#
# ## Simple Feature Engineering
#
# As a first pass at feature engineering, we can group by the month and the customer and calculate numerical aggregations of the purchase data. We'll then join the data for one month to the prediction for the following month to ensure that our data comes before our labels. This means that for each label (a customer-month) we are only building features using data from the previous month.
#
# First we group the data for each customer, and then apply many aggregations to create features. After that we rename the columns for interpretability.

# %%
# Group and aggregate
train_agg = train.groupby(['customer_id', 'month']).agg(['mean', 'max', 'min', 'sum', 'count'])

# Rename the columns
new_cols = []
for col in train_agg.columns.levels[0]:
    for stat in train_agg.columns.levels[1]:
        new_cols.append(f'{col}-{stat}')
        
train_agg.columns = new_cols
train_agg.head()
# Out:
#                    quantity-mean  quantity-max  quantity-min  quantity-sum  \
# customer_id month
# 12346.0     1           0.000000         74215        -74215             0
# 12347.0     1          10.862069            24             3           315
#             4          20.125000           240             3           483
#             6          10.888889            36             2           196
#             8          12.590909            36             3           277
#
#                    quantity-count  price-mean  price-max  price-min  \
# customer_id month
# 12346.0     1                   2    1.716000     1.7160     1.7160
# 12347.0     1                  29    4.163121    21.0375     0.6930
#             4                  24    4.282437    21.0375     0.4125
#             6                  18    4.915167    16.4175     0.4950
#             8                  22    5.118000    21.0375     0.9075
#
# ...

# %% [markdown]
# Since we're aggregating for the previous month, we need to add one to the month and join with the labels.

# %%
train_agg.reset_index(inplace = True)
train_agg['month'] = train_agg['month'] + 1
train_agg.set_index(['customer_id', 'month'], inplace = True)

# %%
train_data = train_labels.merge(train_agg, on = ['customer_id', 'month'], how = 'left')

# %% [markdown]
# Now the stats for the _previous_ month are associated with the label. So the stats for June are going to be used to predict the label for July.
#
# #### Apply Operations to Testing Data
#
# We'll need to do the exact same operations to the testing data to make sure we have the same features. The process is much the same: grouping, aggregating, and merging with the labels (making sure that the previous month's features are associated with the next month's label.)

# %%
test_agg = test.groupby(['customer_id', 'month']).agg(['mean', 'max', 'min', 'sum', 'count'])

new_cols = []
for col in test_agg.columns.levels[0]:
    for stat in test_agg.columns.levels[1]:
        new_cols.append(f'{col}-{stat}')
        
test_agg.columns = new_cols

# Add one to month for joining to labels
test_agg.reset_index(inplace = True)
test_agg['month'] = test_agg['month'] + 1
test_agg.set_index(['customer_id', 'month'], inplace = True)
test_data = test_labels.merge(test_agg, on = ['customer_id', 'month'], how = 'left')

# %% [markdown]
# The information in each row comes from November because the label is for December.

# %%
test_data.head()
# Out:
#    customer_id  label  month  quantity-mean  quantity-max  quantity-min  \
# 0      12347.0      0     12            NaN           NaN           NaN
# 1      12358.0      1     12            NaN           NaN           NaN
# 2      12359.0      0     12            NaN           NaN           NaN
# 3      12362.0      1     12      10.684211          36.0          -3.0
# 4      12364.0      1     12            NaN           NaN           NaN
#
#    quantity-sum  quantity-count  price-mean  price-max     ...      \
# 0           NaN             NaN         NaN        NaN     ...
# 1           NaN             NaN         NaN        NaN     ...
# 2           NaN             NaN         NaN        NaN     ...
# 3         203.0            19.0    6.302132      24.75     ...
# 4           NaN             NaN         NaN        NaN     ...
#
#    minute-mean  minute-max  minute-min  minute-sum  minute-count  hour-mean  \
# ...

# %% [markdown]
# ## Feature Selection
#
# Now let's train and test a model. First, we'll apply some basic feature selection as follows:
#
# 1. Remove any columns with more than 90% missing valuues
# 2. Remove any columns with only a single unique value
# 3. Remove one out of each pair of columns with a correlation above 0.95
#
# The last step removes highly correlated - collinear - features. As we saw in previous notebooks, proper feature selection can help a machine learning model generalize to the test set by removing noise so the signal can be learned.

# %%
from utils import feature_selection

train_data = feature_selection(train_data)
test_data = test_data[train_data.columns]
# Out:
# Original shape:  (23936, 33)
# 0 missing columns with threshold: 90.
# 0 zero variance columns.
# 7 collinear columns removed with threshold: 0.95.
# Total columns removed:  7
# Shape after feature selection: (23936, 26).

# %% [markdown]
# We'll have to impute the missing values. We can also scale the features (to between 0 and 1) although this isn't strictly necessary for the random forest model.

# %%
feature_names = train_data.drop(columns = ['customer_id', 'label', 'month']).columns

pipeline = Pipeline([('imputer', Imputer(strategy = 'median')), 
                      ('scaler', MinMaxScaler())])

# Fit and transform training data
train_ready = pipeline.fit_transform(train_data.drop(columns = ['customer_id', 'label', 'month']))
test_ready = pipeline.transform(test_data.drop(columns = ['customer_id', 'label', 'month']))

# %% [markdown]
# # Modeling
#
# For modeling, we'll use a basic [Random Forest classifier](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) as implemented in Scikit-Learn. Although hyperparameter tuning can have a significant impact on performance, for a comparison between the features, we will stick with the default hyperparameters except for increasing the number of esimators (trees in the forest) from 10 to 1000.
#
# After feature selection and imputation of missing values, our data is ready for training a model.

# %%
model = RandomForestClassifier(n_estimators=1000, n_jobs = -1, random_state=50)
model.fit(train_ready, train_data['label'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#             oob_score=False, random_state=50, verbose=0, warm_start=False)

# %% [markdown]
# Now we can make predictions for December. We'll calculate the four metrics used in automated feature engineering:
#
# 1. Precision: the percentage of customers predicted to spend more than \$500 that actually did
# 2. Recall: the percentage of customers that actually spent more than \$500 that were correctly identified
# 3. F1 score: the harmonic mean of precision and recall
# 4. Receiver Operating Characterisic Area Under the Curve (ROC AUC): a 0 to 1 measure (with 1 being optimal) that measures the performance of a model across a range of thresholds
#
# These metrics are better than straight accuracy, particularly on imbalanced classification problems.

# %%
predictions = model.predict(test_ready)

predictions = model.predict(test_ready)
probs = model.predict_proba(test_ready)[:, 1]

# Calculate metrics
p = precision_score(test_labels['label'], predictions)
r = recall_score(test_labels['label'], predictions)
f = f1_score(test_labels['label'], predictions)
auc = roc_auc_score(test_labels['label'], probs)

print(f'Precision: {round(p, 5)}')
print(f'Recall: {round(r, 5)}')
print(f'F1 Score: {round(f, 5)}')
print(f'ROC AUC: {round(auc, 5)}')

# Feature importances
fi = pd.DataFrame({'feature': feature_names, 'importance': model.feature_importances_})
# Out:
# Precision: 0.37727
# Recall: 0.26101
# F1 Score: 0.30855
# ROC AUC: 0.75145

# %%
from utils import plot_feature_importances
norm_fi = plot_feature_importances(fi)

# %% [markdown]
# Our first attempt at a model does slightly better than the baseline for ROC AUC but performs worse in terms of F1 score. The most important features do make sense though because the total spent previously or the total quantity purchased previously should be good indicators of how much a customer will purchase in the future.
#
# Let's take this code and put it in a function so we can make predictions for any month.
#
# ### Function for Aggregating and Predicting Monthly Data
#
# This function makes a training dataset and predictions for any month by aggregating the data from the previous month. As an example, if we pass in October (10) as the month, then the training labels will come from 9 and before while the testing labels will be from 10. The testing data will come solely from 9. The training data will come from 8 and before, but for each label, we join it to the aggregations only from the previous month. Therefore, we are trying to train a model to predict the sales for each month based only on the previous month's information.
#
# This method ensures that all the data we use is valid for each label.

# %%
def predict_month(month):
    """Make training data and testing data for any month. 
    Measures the performance of a model on the resulting data."""
    
    # Subset data
    train = data[data['month'] < (month - 1)]
    test = data[data['month'] == (month - 1)]
    
    # Extract labels
    train_labels = labels.loc[labels['month'] < month, ['customer_id', 'label', 'month']]
    test_labels = labels.loc[labels['month'] == month, ['customer_id', 'label', 'month']]
    
    # Numeric aggregations
    train_agg = train.groupby(['customer_id', 'month']).agg(['mean', 'max', 'min', 'sum', 'count'])

    # Rename the columns
    new_cols = []
    for col in train_agg.columns.levels[0]:
        for stat in train_agg.columns.levels[1]:
            new_cols.append(f'{col}-{stat}')

    train_agg.columns = new_cols
    
    # Add one to month to tie previous data to label month
    train_agg.reset_index(inplace = True)
    train_agg['month'] = train_agg['month'] + 1
    train_agg.set_index(['customer_id', 'month'], inplace = True)
    
    # Merge with the training labels
    train_data = train_labels.merge(train_agg, on = ['customer_id', 'month'], how = 'left').fillna(0)

    feature_names = train_data.drop(columns = ['customer_id', 'label', 'month']).columns
    
    # Apply same operations to testing data
    test_agg = test.groupby(['customer_id', 'month']).agg(['mean', 'max', 'min', 'sum', 'count'])

    new_cols = []
    for col in test_agg.columns.levels[0]:
        for stat in test_agg.columns.levels[1]:
            new_cols.append(f'{col}-{stat}')

    test_agg.columns = new_cols
    
    # Don't need to add one to the month because test is already subsetted to only one month
    test_data = test_labels.merge(test_agg, on = ['customer_id'], how = 'left').fillna(0)

    pipeline = Pipeline([('imputer', Imputer(strategy = 'median')), 
                          ('scaler', MinMaxScaler())])

    # Fit and transform training data
    train_ready = pipeline.fit_transform(train_data.drop(columns = ['customer_id', 'label', 'month']))
    test_ready = pipeline.transform(test_data.drop(columns = ['customer_id', 'label', 'month']))

    # Train a machine learning model
    model = RandomForestClassifier(n_estimators=1000, n_jobs = -1, random_state=50)
    model.fit(train_ready, train_data['label'])

    predictions = model.predict(test_ready)
    probs = model.predict_proba(test_ready)[:, 1]

    # Calculate metrics
    p = precision_score(test_labels['label'], predictions)
    r = recall_score(test_labels['label'], predictions)
    f = f1_score(test_labels['label'], predictions)
    auc = roc_auc_score(test_labels['label'], probs)

    print(f'Precision: {round(p, 5)}')
    print(f'Recall: {round(r, 5)}')
    print(f'F1 Score: {round(f, 5)}')
    print(f'ROC AUC: {round(auc, 5)}')

    # Feature importances
    fi = pd.DataFrame({'feature': feature_names, 'importance': model.feature_importances_})
    
    return fi

# %%
july_fi = predict_month(7)
# Out:
# Precision: 0.67368
# Recall: 0.14254
# F1 Score: 0.23529
# ROC AUC: 0.66602

# %%
_ = informed_baseline(7)
# Out:
# Precision: 0.41784.
# Recall: 0.39644.
# F1 Score: 0.40686.
# ROC AUC Score: 0.64365.

# %% [markdown]
# The model barely does better than the baseline for July. We can test it on another month to see if these results hold.

# %%
print('Model Results\n')
august_fi = predict_month(8)

print('Baseline Results\n')
_ = informed_baseline(8)
# Out:
# Model Results
#
# Precision: 0.57576
# Recall: 0.12723
# F1 Score: 0.20841
# ROC AUC: 0.656
# Baseline Results
#
# Precision: 0.40089.
# Recall: 0.40179.
# F1 Score: 0.40134.
# ROC AUC Score: 0.66544.

# %% [markdown]
# It should not be that surprising our model doesn't do better than the baseline. Our aggregations are _only using the past month_ of information for each label. In order to try and perform better, we should make features for each label using all the previous data for the customer. That means for the June labels, we do not just use information from May, but from the entire sequence of data for the customer. When implementing this, we need to be careful to not include invalid data in the model. For each label, we can only use _data from prior to the label month_.
#
# # Better Feature Engineering
#
# We can rewrite the code to aggregate information over all the previous months for each label. This time, if we want to make predictions for October (10), our testing labels still come from October, but our testing data will be aggregated for all months from 9 and before. Likewise, for each training label, the corresponding features are built using all the previous data for the customer. We are incorporating more data into each feature (although building the same amount of features) and hence would expect performance to increase.

# %%
def predict_month_expanded(month, return_probs = False):
    """Train and test a model using aggregations from multiple
    previous months. The training data for each label is from
    all previous months. The testing data is also from all 
    previous months."""
    
    train = data[data['month'] < (month - 1)]
    test = data[data['month'] < month ]
    
    # Training labels are from all previous months
    train_labels = labels.loc[labels['month'] < month, ['customer_id', 'label', 'month']]
    
    # Test labels are from a single month
    test_labels = labels.loc[labels['month'] == month, ['customer_id', 'label', 'month']]
    
    # Iterate through each month
    for i, train_month in enumerate(train_labels['month'].unique()):

        # Training data is from all months before the label
        train_agg = train.loc[train['month'] < train_month].groupby(['customer_id']).agg(['mean', 'max', 'min', 'sum', 'count'])

        # Rename the columns
        new_cols = []
        for col in train_agg.columns.levels[0]:
            for stat in train_agg.columns.levels[1]:
                new_cols.append(f'{col}-{stat}')

        train_agg.columns = new_cols
        train_agg.reset_index(inplace = True)
        
        # Set the month for joining to the labels
        train_agg['month'] = train_month
        
        # Create a dataframe of the training data
        if i == 0:
             all_train_data = train_agg.copy()
                
        else:
            all_train_data = all_train_data.append(train_agg)
    
    # Join with the labels on the customer and month (the month is already correct)
    all_train_data = train_labels.merge(all_train_data, on = ['customer_id', 'month'], how = 'left')
    feature_names = all_train_data.drop(columns = ['customer_id', 'label', 'month']).columns
    
    # Test data is already subsetted to all previous months
    test_agg = test.groupby(['customer_id']).agg(['mean', 'max', 'min', 'sum', 'count'])
    
    # Rename the columns
    new_cols = []
    for col in test_agg.columns.levels[0]:
        for stat in test_agg.columns.levels[1]:
            new_cols.append(f'{col}-{stat}')

    test_agg.columns = new_cols
    
    # Merge the test data with the test labels
    test_data = test_labels.merge(test_agg, on = ['customer_id'], how = 'left')

    pipeline = Pipeline([('imputer', Imputer(strategy = 'median')), 
                          ('scaler', MinMaxScaler())])

    # Impute the missing values and scale
    train_ready = pipeline.fit_transform(all_train_data.drop(columns = ['customer_id', 'label', 'month']))
    test_ready = pipeline.transform(test_data.drop(columns = ['customer_id', 'label', 'month']))

    # Machine learning modeling
    model = RandomForestClassifier(n_estimators=1000, n_jobs = -1, random_state=50)
    model.fit(train_ready, all_train_data['label'])

    # Predictions
    predictions = model.predict(test_ready)
    predictions = model.predict(test_ready)
    probs = model.predict_proba(test_ready)[:, 1]

    # Calculate metrics
    p = precision_score(test_labels['label'], predictions)
    r = recall_score(test_labels['label'], predictions)
    f = f1_score(test_labels['label'], predictions)
    auc = roc_auc_score(test_labels['label'], probs)

    print(f'Precision: {round(p, 5)}')
    print(f'Recall: {round(r, 5)}')
    print(f'F1 Score: {round(f, 5)}')
    print(f'ROC AUC: {round(auc, 5)}')

    # Feature importances
    fi = pd.DataFrame({'feature': feature_names, 'importance': model.feature_importances_})
    
    if return_probs:
        return fi, probs
    
    return fi

# %%
june_fi = predict_month_expanded(6)
# Out:
# Precision: 0.56634
# Recall: 0.4108
# F1 Score: 0.47619
# ROC AUC: 0.7498

# %%
september_fi = predict_month_expanded(9)
# Out:
# Precision: 0.62869
# Recall: 0.23764
# F1 Score: 0.34491
# ROC AUC: 0.73444

# %%
_ = plot_feature_importances(september_fi)

# %%
december_fi = predict_month_expanded(12)
# Out:
# Precision: 0.32812
# Recall: 0.46226
# F1 Score: 0.38381
# ROC AUC: 0.791

# %%
_ = plot_feature_importances(december_fi)

# %% [markdown]
# When comparing these results to the baseline guesses, we now see that the model is better than simply predicting a customer will spend the same this month as they did the previous month.
#
# We can conclude that the manual feature engineering now outperforms the baseline if we use all of the previous information. Looking at the feature importances, they seem to make sense in the domain of the problem. However, I'm not entirely convinced that all of the data is allowable for this problem. Taking on this problem by hand introduces many opportunities for error. Companies routinely struggle with the issue of using only valid data and often will design a model that does well in development but then fails in deployment because it was trained on data that won't actually be available in the real world - for example data that occurs after the label is known.
#
# In the automated engineering notebook, we saw that Featuretools can automatically handle the cutoff times for us, ensuring that all of our features are built using valid data. If the method exists and can be used to safely build features, then what's the downside to using it as opposed to doing everything by hand?
#
# Finally, let's take a look at a comparison between manual and automated feature engineering performance.

# %% [markdown]
# # Comparison to Automated Feature Engineering
#
# To compare the performance of Automated Feature Engineering, the baseline model, and manual feature engineering, we can plot the [Receiver Operating Characteristic](https://en.wikipedia.org/wiki/Receiver_operating_characteristic) curves for each month. ROC curves show the false positive rate versus the true positive rate across a range of thresholds for classifiying a prediction as positive. A ROC curve that is strictly higher than the curve for another model indicates a better classifier.

# %%
# %%capture

# Make predictions for each month
for month in range(4, 13):
    
    # Record predictions
    _, probs = predict_month_expanded(month, True)
    temp_df = pd.DataFrame({'Manual': probs, 'month': month})
    
    if month == 4:
        probs_df = temp_df.copy()
    
    else:
        probs_df = probs_df.append(temp_df)

# %%
probs_df['label'] = list(labels.loc[labels['month'] > 3]['label'])

# %% [markdown]
# We'll read in the automated probabilities that we already forecast.

# %%
auto_probs = pd.read_csv('../input/auto_probs.csv', index_col = 0)
auto_probs.head()
# Out:
#    Automated  month  label
# 0      0.140      4      0
# 1      0.039      4      1
# 2      0.134      4      1
# 3      0.089      4      0
# 4      0.325      4      0

# %%
import calendar
plt.figure(figsize = (24, 24))
plt.style.use('fivethirtyeight')
plt.rcParams['font.weight'] = 'normal'

# Plot 4 months
for month, month_data in probs_df.groupby('month'):
    
    if month < 9:
        next
    else:
        
        # Subset
        auto_probs_month = auto_probs.loc[auto_probs['month'] == month].copy()
        
        plt.subplot(2, 2, month - 8)
        # Informed baseline
        baseline = informed_baseline(month, quiet = True)
        fpr, tpr, _ = roc_curve(baseline['label'], baseline['probability'])
        baseline_score = roc_auc_score(baseline['label'], baseline['probability'])
        print(f'\n{calendar.month_name[month]} ROC AUC Performance:')
        print(f'Baseline: {round(baseline_score, 5)}') 
        plt.plot(fpr, tpr, label = 'Baseline', color = 'black')


        # Manual Predictions
        fpr, tpr, _ = roc_curve(month_data['label'], month_data['Manual'])
        manual_score = roc_auc_score(month_data['label'], month_data['Manual'])
        print(f'Manual: {round(manual_score, 5)}')
        plt.plot(fpr, tpr, label = 'Manual', color = 'blue')

        # Automated Predictions
        fpr, tpr, _ = roc_curve(auto_probs_month['label'], auto_probs_month['Automated'])
        auto_score = roc_auc_score(auto_probs_month['label'], auto_probs_month['Automated'])
        print(f'Automated: {round(auto_score, 5)}')
        plt.plot(fpr, tpr, label = 'Automated', color = 'forestgreen')
        
        plt.xlabel('False Positive Rate', size = 28); plt.ylabel('True Positive Rate', size = 28);

        if month == 9:
            plt.legend(prop = {'size': 40});

        plt.xticks(size = 24); plt.yticks(size = 24);
        plt.title(f'{calendar.month_name[month]} Sales', size = 30);

plt.suptitle('ROC Comparison of Automated vs Manual Feature Engineering', size = 40, y = 0.96)
plt.subplots_adjust();
# Out:
# September ROC AUC Performance:
# Baseline: 0.62499
# Manual: 0.73444
# Automated: 0.87649
#
# October ROC AUC Performance:
# Baseline: 0.61645
# Manual: 0.72241
# Automated: 0.85911
#
# November ROC AUC Performance:
# Baseline: 0.61947
# Manual: 0.74077
# Automated: 0.8799
#
# December ROC AUC Performance:
# Baseline: 0.69502
# Manual: 0.791
# Automated: 0.90864

# %% [markdown]
# For the final 4 months (when theoretically our models should be best because they are training on more examples) the automated features significantly outperform the manual engineering features. Both sets of features outperform the baseline indicating that machine learning is applicable to this problem.

# %%
plt.figure(figsize = (24, 32))
plt.style.use('fivethirtyeight')
plt.rcParams['font.weight'] = 'normal'

for month, month_data in probs_df.groupby('month'):

    
    auto_probs_month = auto_probs.loc[auto_probs['month'] == month].copy()

    plt.subplot(5, 2, month - 3)

    # Informed baseline
    baseline = informed_baseline(month, quiet = True)
    fpr, tpr, _ = roc_curve(baseline['label'], baseline['probability'])
    baseline_score = roc_auc_score(baseline['label'], baseline['probability'])
    print(f'\n{calendar.month_name[month]} ROC AUC Performance:')
    print(f'Baseline: {round(baseline_score, 5)}')

    plt.plot(fpr, tpr, label = 'Baseline', color = 'black')


    # Manual Predictions
    fpr, tpr, _ = roc_curve(month_data['label'], month_data['Manual'])
    manual_score = roc_auc_score(month_data['label'], month_data['Manual'])
    print(f'Manual: {round(manual_score, 5)}')
    plt.plot(fpr, tpr, label = 'Manual', color = 'blue')

    # Automated Predictions
    fpr, tpr, _ = roc_curve(auto_probs_month['label'], auto_probs_month['Automated'])
    plt.plot(fpr, tpr, label = 'Automated', color = 'forestgreen')
    auto_score = roc_auc_score(auto_probs_month['label'], auto_probs_month['Automated'])
    print(f'Automated: {round(auto_score, 5)}')

    plt.xlabel('False Positive Rate', size = 28); plt.ylabel('True Positive Rate', size = 28);

    if month == 4:
        plt.legend(prop = {'size': 40});

    plt.xticks(size = 24); plt.yticks(size = 24);
    plt.title(f'{calendar.month_name[month]} Sales', size = 30);

    plt.suptitle('ROC Comparison of Automated vs Manual Feature Engineering', size = 40, y = 0.96)
    plt.subplots_adjust();
# Out:
# April ROC AUC Performance:
# Baseline: 0.63254
# Manual: 0.73478
# Automated: 0.82243
#
# May ROC AUC Performance:
# Baseline: 0.62495
# Manual: 0.73304
# Automated: 0.85958
#
# June ROC AUC Performance:
# Baseline: 0.67321
# Manual: 0.7498
# Automated: 0.87037
#
# July ROC AUC Performance:
# Baseline: 0.64365
# Manual: 0.75821
# Automated: 0.89522
#
# August ROC AUC Performance:
# Baseline: 0.66544
# Manual: 0.7862
# Automated: 0.91289
#
# September ROC AUC Performance:
# Baseline: 0.62499
# Manual: 0.73444
# Automated: 0.87649
#
# October ROC AUC Performance:
# Baseline: 0.61645
# Manual: 0.72241
# Automated: 0.85911
#
# November ROC AUC Performance:
# Baseline: 0.61947
# Manual: 0.74077
# Automated: 0.8799
#
# December ROC AUC Performance:
# Baseline: 0.69502
# Manual: 0.791
# Automated: 0.90864

# %% [markdown]
# Looking at 9 months, we see the exact same story: automated feature engineering outperforms manual feature engineering. There is no conclusive trend in performance over time which indicates that using more training examples does not help our model that much.
#
# Moreover, we should have more confidence that the automated features are valid because we used a cutoff time to filter the data in Featuretools rather than implementing the logic ourselves.

# %% [markdown]
# # Conclusions
#
# Despite much more time spent on manual feature engineering than automated feature engineering (8 hours compared to 1 hour), the automated approach took a decisive victory. The manual approach suffered because I had to be extremely cautious about not using invalid data and therefore had to resort to basically re-implementing the functionality of Featuretools. I'm still not quite sure if my features from the manual engineering are entirely valid!
#
# Overall, the takeaways from the retail spending project were:
#
# * For a smaller time investment, automated feature engineering delivers a significantly better model.
# * Featuretools automatically is able to filter data based on an array of cutoff times leaving us free from having to worry about using invalid data
# * The most important features from both approaches to feature engineering are useful in the context of the problem
# * By preventing data leakage, automated feature engineering ensures that model deployment will be as successful as development
#
# Yes, we could probably achieve the same results manually as we do with featuretools with more time spent on the problem, but if a superior tool exists, then why would we not take advantage of it? __Data science is about extracting meaning from data using the right tool for the job, and automated feature engineering is clearly the correct choice for this and many other machine learning problems.__
