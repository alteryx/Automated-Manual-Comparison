# %% [markdown]
# In this notebook, we will work on partioning the data based on a list of user ids. The purpose is to create smaller entitysets that will fit in memory for calculating the feature matrix.

# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# featuretools for automated feature engineering
import featuretools as ft

import featuretools.variable_types as vtypes

import sys
import psutil

import os

# %%
# Read in the datasets and replace the anomalous values
app_train = pd.read_csv('../../data/kaggle_home_credit/application_train.csv').replace({365243: np.nan})
app_test = pd.read_csv('../../data/kaggle_home_credit/application_test.csv').replace({365243: np.nan})
bureau = pd.read_csv('../../data/kaggle_home_credit/bureau.csv').replace({365243: np.nan})
bureau_balance = pd.read_csv('../../data/kaggle_home_credit/bureau_balance.csv').replace({365243: np.nan})
cash = pd.read_csv('../../data/kaggle_home_credit/POS_CASH_balance.csv').replace({365243: np.nan})
credit = pd.read_csv('../../data/kaggle_home_credit/credit_card_balance.csv').replace({365243: np.nan})
previous = pd.read_csv('../../data/kaggle_home_credit/previous_application.csv').replace({365243: np.nan})
installments = pd.read_csv('../../data/kaggle_home_credit/installments_payments.csv').replace({365243: np.nan})

app_test['TARGET'] = np.nan

# Join together training and testing
app = app_train.append(app_test, ignore_index = True, sort = True)

# All ids should be integers
for index in ['SK_ID_CURR', 'SK_ID_PREV', 'SK_ID_BUREAU']:
    for dataset in [app, bureau, bureau_balance, cash, credit, previous, installments]:
        if index in list(dataset.columns):
            # Convert to integers after filling in missing values (not sure why values are missing)
            dataset[index] = dataset[index].fillna(0).astype(np.int64)

# Need `SK_ID_CURR` in every dataset
bureau_balance = bureau_balance.merge(bureau[['SK_ID_CURR', 'SK_ID_BUREAU']], 
                                      on = 'SK_ID_BUREAU', how = 'left')


# Set the index for locating
for dataset in [app, bureau, bureau_balance, cash, credit, previous, installments]:
    dataset.set_index('SK_ID_CURR', inplace = True)

# %%
def create_partition(user_list, partition):
    """Creates an entityset with only the users in `user_list`. 
       Main purpose is partioning data"""
    
    # Subset based on user list
    app_subset = app[app.index.isin(user_list)].copy().reset_index()
    bureau_subset = bureau[bureau.index.isin(user_list)].copy().reset_index()
    
    # Drop SK_ID_CURR from bureau_balance, cash, credit, and installments
    bureau_balance_subset = bureau_balance[bureau_balance.index.isin(user_list)].copy().reset_index(drop = True)
    cash_subset = cash[cash.index.isin(user_list)].copy().reset_index(drop = True)
    credit_subset = credit[credit.index.isin(user_list)].copy().reset_index(drop = True)
    previous_subset = previous[previous.index.isin(user_list)].copy().reset_index()
    installments_subset = installments[installments.index.isin(user_list)].copy().reset_index(drop = True)
    
    directory = '../../data/kaggle_home_credit/partitions/p%d' % (partition + 1)
    os.makedirs(directory)
    
    app_subset.to_csv('%s/app.csv' % directory, index = False)
    bureau_subset.to_csv('%s/bureau.csv' % directory, index = False)
    bureau_balance_subset.to_csv('%s/bureau_balance.csv' % directory, index = False)
    cash_subset.to_csv('%s/cash.csv' % directory, index = False)
    credit_subset.to_csv('%s/credit.csv' % directory, index = False)
    previous_subset.to_csv('%s/previous.csv' % directory, index = False)
    installments_subset.to_csv('%s/installments.csv' % directory, index = False)

    print('Saved all files in partition {} to {}.'.format(partition + 1,directory))

# %%
# Break into 10 chunks
chunk_size = app.shape[0] // 100

# Construct an id list
id_list = [list(app.iloc[i:i+chunk_size].index) for i in range(0, app.shape[0], chunk_size)]

# %%
from itertools import chain

# Sanity check that we have not missed any ids
print('Number of ids in id_list:         {}.'.format(len(list(chain(*id_list)))))
print('Total length of application data: {}.'.format(len(app)))
# Out:
# Number of ids in id_list:         356255.
# Total length of application data: 356255.

# %%
for i, ids in enumerate(id_list):
    # Create a partition based on the ids
    create_partition(ids, i)
# Out:
# Saved all files in partition 1 to ../../data/kaggle_home_credit/partitions/p1.
# Saved all files in partition 2 to ../../data/kaggle_home_credit/partitions/p2.
# Saved all files in partition 3 to ../../data/kaggle_home_credit/partitions/p3.
# Saved all files in partition 4 to ../../data/kaggle_home_credit/partitions/p4.
# Saved all files in partition 5 to ../../data/kaggle_home_credit/partitions/p5.
# Saved all files in partition 6 to ../../data/kaggle_home_credit/partitions/p6.
# Saved all files in partition 7 to ../../data/kaggle_home_credit/partitions/p7.
# Saved all files in partition 8 to ../../data/kaggle_home_credit/partitions/p8.
# Saved all files in partition 9 to ../../data/kaggle_home_credit/partitions/p9.
# Saved all files in partition 10 to ../../data/kaggle_home_credit/partitions/p10.
# Saved all files in partition 11 to ../../data/kaggle_home_credit/partitions/p11.
# Saved all files in partition 12 to ../../data/kaggle_home_credit/partitions/p12.
# Saved all files in partition 13 to ../../data/kaggle_home_credit/partitions/p13.
# Saved all files in partition 14 to ../../data/kaggle_home_credit/partitions/p14.
# Saved all files in partition 15 to ../../data/kaggle_home_credit/partitions/p15.
# Saved all files in partition 16 to ../../data/kaggle_home_credit/partitions/p16.
# Saved all files in partition 17 to ../../data/kaggle_home_credit/partitions/p17.
# Saved all files in partition 18 to ../../data/kaggle_home_credit/partitions/p18.
# Saved all files in partition 19 to ../../data/kaggle_home_credit/partitions/p19.
# Saved all files in partition 20 to ../../data/kaggle_home_credit/partitions/p20.
# Saved all files in partition 21 to ../../data/kaggle_home_credit/partitions/p21.
# Saved all files in partition 22 to ../../data/kaggle_home_credit/partitions/p22.
# Saved all files in partition 23 to ../../data/kaggle_home_credit/partitions/p23.
# Saved all files in partition 24 to ../../data/kaggle_home_credit/partitions/p24.
# Saved all files in partition 25 to ../../data/kaggle_home_credit/partitions/p25.
# Saved all files in partition 26 to ../../data/kaggle_home_credit/partitions/p26.
# Saved all files in partition 27 to ../../data/kaggle_home_credit/partitions/p27.
# Saved all files in partition 28 to ../../data/kaggle_home_credit/partitions/p28.
# Saved all files in partition 29 to ../../data/kaggle_home_credit/partitions/p29.
# Saved all files in partition 30 to ../../data/kaggle_home_credit/partitions/p30.
# Saved all files in partition 31 to ../../data/kaggle_home_credit/partitions/p31.
# Saved all files in partition 32 to ../../data/kaggle_home_credit/partitions/p32.
# Saved all files in partition 33 to ../../data/kaggle_home_credit/partitions/p33.
# Saved all files in partition 34 to ../../data/kaggle_home_credit/partitions/p34.
# Saved all files in partition 35 to ../../data/kaggle_home_credit/partitions/p35.
# Saved all files in partition 36 to ../../data/kaggle_home_credit/partitions/p36.
# Saved all files in partition 37 to ../../data/kaggle_home_credit/partitions/p37.
# Saved all files in partition 38 to ../../data/kaggle_home_credit/partitions/p38.
# Saved all files in partition 39 to ../../data/kaggle_home_credit/partitions/p39.
# Saved all files in partition 40 to ../../data/kaggle_home_credit/partitions/p40.
# Saved all files in partition 41 to ../../data/kaggle_home_credit/partitions/p41.
# Saved all files in partition 42 to ../../data/kaggle_home_credit/partitions/p42.
# Saved all files in partition 43 to ../../data/kaggle_home_credit/partitions/p43.
# Saved all files in partition 44 to ../../data/kaggle_home_credit/partitions/p44.
# Saved all files in partition 45 to ../../data/kaggle_home_credit/partitions/p45.
# Saved all files in partition 46 to ../../data/kaggle_home_credit/partitions/p46.
# Saved all files in partition 47 to ../../data/kaggle_home_credit/partitions/p47.
# Saved all files in partition 48 to ../../data/kaggle_home_credit/partitions/p48.
# Saved all files in partition 49 to ../../data/kaggle_home_credit/partitions/p49.
# Saved all files in partition 50 to ../../data/kaggle_home_credit/partitions/p50.
# Saved all files in partition 51 to ../../data/kaggle_home_credit/partitions/p51.
# Saved all files in partition 52 to ../../data/kaggle_home_credit/partitions/p52.
# Saved all files in partition 53 to ../../data/kaggle_home_credit/partitions/p53.
# Saved all files in partition 54 to ../../data/kaggle_home_credit/partitions/p54.
# Saved all files in partition 55 to ../../data/kaggle_home_credit/partitions/p55.
# Saved all files in partition 56 to ../../data/kaggle_home_credit/partitions/p56.
# Saved all files in partition 57 to ../../data/kaggle_home_credit/partitions/p57.
# Saved all files in partition 58 to ../../data/kaggle_home_credit/partitions/p58.
# Saved all files in partition 59 to ../../data/kaggle_home_credit/partitions/p59.
# Saved all files in partition 60 to ../../data/kaggle_home_credit/partitions/p60.
# Saved all files in partition 61 to ../../data/kaggle_home_credit/partitions/p61.
# Saved all files in partition 62 to ../../data/kaggle_home_credit/partitions/p62.
# Saved all files in partition 63 to ../../data/kaggle_home_credit/partitions/p63.
# Saved all files in partition 64 to ../../data/kaggle_home_credit/partitions/p64.
# Saved all files in partition 65 to ../../data/kaggle_home_credit/partitions/p65.
# Saved all files in partition 66 to ../../data/kaggle_home_credit/partitions/p66.
# Saved all files in partition 67 to ../../data/kaggle_home_credit/partitions/p67.
# Saved all files in partition 68 to ../../data/kaggle_home_credit/partitions/p68.
# Saved all files in partition 69 to ../../data/kaggle_home_credit/partitions/p69.
# Saved all files in partition 70 to ../../data/kaggle_home_credit/partitions/p70.
# Saved all files in partition 71 to ../../data/kaggle_home_credit/partitions/p71.
# Saved all files in partition 72 to ../../data/kaggle_home_credit/partitions/p72.
# Saved all files in partition 73 to ../../data/kaggle_home_credit/partitions/p73.
# Saved all files in partition 74 to ../../data/kaggle_home_credit/partitions/p74.
# Saved all files in partition 75 to ../../data/kaggle_home_credit/partitions/p75.
# Saved all files in partition 76 to ../../data/kaggle_home_credit/partitions/p76.
# Saved all files in partition 77 to ../../data/kaggle_home_credit/partitions/p77.
# Saved all files in partition 78 to ../../data/kaggle_home_credit/partitions/p78.
# Saved all files in partition 79 to ../../data/kaggle_home_credit/partitions/p79.
# Saved all files in partition 80 to ../../data/kaggle_home_credit/partitions/p80.
# Saved all files in partition 81 to ../../data/kaggle_home_credit/partitions/p81.
# Saved all files in partition 82 to ../../data/kaggle_home_credit/partitions/p82.
# Saved all files in partition 83 to ../../data/kaggle_home_credit/partitions/p83.
# Saved all files in partition 84 to ../../data/kaggle_home_credit/partitions/p84.
# Saved all files in partition 85 to ../../data/kaggle_home_credit/partitions/p85.
# Saved all files in partition 86 to ../../data/kaggle_home_credit/partitions/p86.
# Saved all files in partition 87 to ../../data/kaggle_home_credit/partitions/p87.
# Saved all files in partition 88 to ../../data/kaggle_home_credit/partitions/p88.
# Saved all files in partition 89 to ../../data/kaggle_home_credit/partitions/p89.
# Saved all files in partition 90 to ../../data/kaggle_home_credit/partitions/p90.
# Saved all files in partition 91 to ../../data/kaggle_home_credit/partitions/p91.
# Saved all files in partition 92 to ../../data/kaggle_home_credit/partitions/p92.
# Saved all files in partition 93 to ../../data/kaggle_home_credit/partitions/p93.
# Saved all files in partition 94 to ../../data/kaggle_home_credit/partitions/p94.
# Saved all files in partition 95 to ../../data/kaggle_home_credit/partitions/p95.
# Saved all files in partition 96 to ../../data/kaggle_home_credit/partitions/p96.
# Saved all files in partition 97 to ../../data/kaggle_home_credit/partitions/p97.
# Saved all files in partition 98 to ../../data/kaggle_home_credit/partitions/p98.
# Saved all files in partition 99 to ../../data/kaggle_home_credit/partitions/p99.
# Saved all files in partition 100 to ../../data/kaggle_home_credit/partitions/p100.
# Saved all files in partition 101 to ../../data/kaggle_home_credit/partitions/p101.
