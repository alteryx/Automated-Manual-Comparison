# %% [markdown]
# ![](../../images/featuretools.png)
#
# # Predicting Remaining Useful Life using Automated Feature Engineering in Featuretools
#
# In this notebook, we will look at an automated approach to feature engineering for the time-series problem of predicting how long an engine will run. Predicting how long an engine, or any part for that matter, will last, is an important problem in engineering that we can address using historical data and machine learning. We'll use [Featuretools, an open-source library](https://www.featuretools.com/) for automated feature engineering to create a rich set of features in order to train machine learning models.
#
# In a previous notebook, we covered this task using manual feature engineering, with the basic implementation achieving:
#
# __5-fold Cross Validation MAPE: 46.62 Test MAPE: 51.48. These features took 120 minutes to build including the time necessary for understanding the data and for implementing the code.__
#
# ## Data
#
# In the manual notebook, we defined the prediction problem by selecting Cutoff Points (which we called a `prediction_point`) in the data for each engine and then using the label as the number of cycles from this point to failure. The observational data was subsetted to only periods from before this prediction point to ensure the data is valid for each engine. To make a fair comparison between manual and automated approaches, we'll load in the same exact prediction problem and data. The original data can be found [here](https://github.com/hankroark/Turbofan-Engine-Degradation/tree/master/CMAPSSData)
#
# The metric we established is __Mean Absolute Percentage Error (MAPE)__, an interpretable measure that is the percentage error from our predictions. We'll measure MAPE both in 5-fold cross validation on the training data and on the test data (for which we know the true labels).
#
# ## Roadmap
#
# This is a fairly straightforward time-series problem once we have the data segmented into labels and allowable training data. Automated feature engineering using Featuretools involves the following steps
#
# 1. Create an EntitySet and add entities to it
#     * Add a dataframe and then normalize to create parent-child tables
# 2. Add relationships between Entities
#     * When normalizing tables this is done automatically
# 3. Run deep feature synthesis using basic primitives
# 4. Define custom primitives to enhance the capabilities of featuretools
# 5. Evaluate feature sets using a default Random Forest Regressor
# 6. Optimize the machine learning model using random search
#
# Along the way, we'll try out some of the more advanced aspects of Featuretools that can help us get the most from this library. This problem is a good introduction to some of the time capabilities of Featuretools, noticeably the ability to create custom primitives that can incorporate our domain knowledge into a set of features.

# %%
import pandas as pd
import numpy as np

import featuretools as ft
import featuretools.variable_types as vtypes

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import Imputer

% load_ext autoreload
% autoreload 2
% aimport utils
from utils import feature_selection, plot_feature_importances, evaluate, random_search

# %% [markdown]
# This is the same data used in the manual feature engineering notebook.

# %%
train = pd.read_csv('../input/train_obs.csv').reset_index()
train.head()
# Out:
#    index  engine_no  operational_setting_1  operational_setting_2  \
# 0      0          1                34.9983                 0.8400
# 1      1          1                41.9982                 0.8408
# 2      2          1                24.9988                 0.6218
# 3      3          1                42.0077                 0.8416
# 4      4          1                25.0005                 0.6203
#
#    operational_setting_3  sensor_measurement_1  sensor_measurement_10  \
# 0                  100.0                449.44                   1.02
# 1                  100.0                445.00                   1.02
# 2                   60.0                462.54                   0.94
# 3                  100.0                445.00                   1.02
# 4                   60.0                462.54                   0.94
#
#    sensor_measurement_11  sensor_measurement_12  sensor_measurement_13  \
# 0                  42.02                 183.06                2387.72
# ...

# %% [markdown]
# # EntitySet and Entities
#
#
# First we'll define an `EntitySet` and add our entities to it. This is a single data structure that keeps track of all our data tables and the relationships between them. Our data does have a `time_index` so we want to specify that when we add it as an `entity` to the EntitySet.

# %%
es = ft.EntitySet(id = 'engines')

# Make an entity from the observations data
es = es.entity_from_dataframe(dataframe = train,
                              entity_id = 'obs',
                              index = 'index', 
                              time_index = 'time')

# %% [markdown]
# ## Normalizing Data
#
# In the manual engineering notebook, we created features by grouping and aggregating the observations for each engine and then creating a final table with one row for each engine. We'll use the same idea in Featuretools, but our method will be slightly different.
#
# First we'll _normalize_ the `obs` data by the engine. This will create a table with one row for each engine where the index is the `engine_no`. Then, when we build features from the observational data, we can specify that we want to build the features for the engines. Featuretools will automatically perform the aggregations of the observations on each engine for us. We can normalize an entity using `normalize_entity` with the following arguments:
#
# * `base_entity_id`: the table where our new table is drawn from. In this case, the `obs` table because each engine is represented multiple times in this data
# * `new_entity_id` the name given to the new table
# * `index`: the unique identifier for the table. This is the `engine_no` because it is unique to each engine
#
# ### Relationships
#
# Normally, we have to explicitly define the table relationships when using Featuretools, specifying the parent variable and the child  variable. However, when using `normalize_entity`, this is done for us! The function will add a relationship mapping the `index` in the new entity to the `index` in the original entity.

# %%
# Create a new table with unique engines
es.normalize_entity(base_entity_id = 'obs',
                    new_entity_id = 'engines', 
                    index = 'engine_no')
es
# Out:
# Entityset: engines
#   Entities:
#     obs [Rows: 27403, Columns: 33]
#     engines [Rows: 260, Columns: 2]
#   Relationships:
#     obs.engine_no -> engines.engine_no

# %% [markdown]
# And with that, we are good to go! We can run deep feature synthesis on our data right away and get started creating hundreds of features.
#
# # Deep Feature Synthesis and Feature Primitives
#
# To understand [Deep Feature Synthesis (DFS)](https://www.featurelabs.com/blog/deep-feature-synthesis/), we first have to grasp feature primitives. A feature primitive at a very high-level is an operation applied to data to create a feature. Primitives are often operations that we would apply by hand to build our features. In Featuretools these simple calculations can be stacked on top of each other to create complex deep features. Feature primitives fall into two categories:
#
# * __Aggregation__ (`agg`): function that groups together child datapoints for each parent and then calculates a statistic such as mean, min, max, or standard deviation. An example is calculating the maximum loan amount for each client. An aggregation works across multiple tables using relationships between tables.
# * __Transformation__ (`trans`): an operation applied to one or more columns in a single table. An example would be extracting the day from dates, or finding the difference between two columns in one table.
#
# Deep feature synthesis takes feature primitives and stacks them on top of each other to create new features. The depth of a feature is the number of primitives stacked, so, for example, taking the mean of a maximum would be a feature of depth 2. Because we only have two tables in this case, we'll first stick to features with depth of 1. When doing manual engineering, all of the features we created were essentially "deep features" with a depth of 1 since we made them by aggregating child observations for each parent. Featuretools will do this for us in deep feature synthesis but with code that can applied to any problem rather than one specific dataset.
#
# Let's take a look at a basic example of running deep feature synthesis using `ft.dfs`. We'll specify to build the features for each engine (`target_entity = engines`), list a few `agg` and `trans` primitives, a maximum depth of 1, and `n_jobs=-1` to run on all cores.

# %%
feature_matrix, feature_names = ft.dfs(entityset=es, target_entity='engines',
                                       agg_primitives = ['min', 'max', 'mean', 
                                                         'count', 'sum'],
                                       trans_primitives = ['cum_mean', 'cum_sum'],
                                       max_depth = 1, n_jobs = -1, verbose = 1)
feature_matrix.head()
# Out:
# Built 121 features
# EntitySet scattered to workers in 2.541 seconds
# Elapsed: 00:01 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 10/10 chunks
#            MIN(obs.operational_setting_1)  MIN(obs.operational_setting_2)  \
# engine_no
# 1                                  0.0000                             0.0
# 2                                  0.0000                             0.0
# 3                                  0.0002                             0.0
# 4                                  0.0004                             0.0
# 5                                  0.0008                             0.0
#
#            MIN(obs.operational_setting_3)  MIN(obs.sensor_measurement_1)  \
# engine_no
# 1                                    60.0                          445.0
# 2                                    60.0                          445.0
# 3                                    60.0                          445.0
# ...

# %% [markdown]
# With about 15 minutes of total work, we now have 120+ features for modeling. We can easily make many more features by specifying more `primitives`. In contrast to manual feature engineering where adding a new feature might mean hours of work, Featuretools lets us drastically increase the number of features by simply adding another primitive which will stack on top of the existing features where possible.

# %% [markdown]
# ## Testing Data
#
# We'll want to apply the same operations (make the same features) to our test data. We can load in the test data and create a separate `EntitySet` (for this problem, a separate `EntitySet` is probably the easiest way to keep track of the training and testing information).

# %%
test = pd.read_csv('../input/test_obs.csv').reset_index()
test_es = ft.EntitySet(id = 'test_engines')
test_es = test_es.entity_from_dataframe(dataframe = test,
                                        entity_id='obs', 
                                        index = 'index',
                                        time_index = 'time')

# %% [markdown]
# We'll want to normalize this table as well by each engine.

# %%
test_es.normalize_entity(base_entity_id='obs',
                         new_entity_id = 'engines', 
                         index = 'engine_no')
test_es
# Out:
# Entityset: test_engines
#   Entities:
#     obs [Rows: 33991, Columns: 33]
#     engines [Rows: 259, Columns: 2]
#   Relationships:
#     obs.engine_no -> engines.engine_no

# %% [markdown]
# We already have the features we need to make, `feature_names`, so we don't need to run `ft.dfs` but instead can use `calculate_feature_matrix` passing the list of features. This will create the exact same features for the testing data are in the training data.

# %%
test_feature_matrix = ft.calculate_feature_matrix(feature_names, entityset=test_es, 
                                                   n_jobs = -1, verbose = 1)
test_feature_matrix.head()
# Out:
# EntitySet scattered to workers in 2.395 seconds
# Elapsed: 00:01 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 11/11 chunks
#            MIN(obs.operational_setting_1)  MIN(obs.operational_setting_2)  \
# engine_no
# 1                                  0.0002                             0.0
# 2                                  0.0005                             0.0
# 3                                  0.0001                             0.0
# 4                                  0.0002                             0.0
# 5                                  0.0000                             0.0
#
#            MIN(obs.operational_setting_3)  MIN(obs.sensor_measurement_1)  \
# engine_no
# 1                                    60.0                          445.0
# 2                                    60.0                          445.0
# 3                                    60.0                          445.0
# ...

# %% [markdown]
# # Modeling
#
# We can now use the training data for training a model and the testing data for making predictions. First we'll load in the labels.

# %%
# Load in the labels for training 
train_labels = np.array(pd.read_csv('../input/engines_4.csv')['label']).reshape((-1, ))
test_labels = np.array(pd.read_csv('../input/RUL_FD002.txt', sep=' ', 
                                   header=-1, names=['label'], index_col=False)['label']).reshape((-1, ))

# %% [markdown]
# ### Feature Selection
#
# We can use the `feature_selection` function previously developed in order to limit the amout of features (because some may be irrelevant or redudant). In the manual feature engineering notebook, we saw the importance of feature selection as it increased our score from no better than guessing to a model that reduced the baseline error by 75%.

# %%
feature_matrix = feature_selection(feature_matrix, correlation_threshold=0.9)
test_feature_matrix = test_feature_matrix[feature_matrix.columns]
# Out:
# Original shape:  (260, 121)
# 15 missing columns with threshold: 90.
# 15 zero variance columns.
# 63 collinear columns removed with threshold: 0.9.
# Total columns removed:  93
# Shape after feature selection: (260, 28).

# %%
preds, fi = evaluate(feature_matrix, train_labels, test_feature_matrix, test_labels)
# Out:
# 5-fold CV MAPE: 46.13 with std: 4.33
# Test MAPE: 48.95.

# %% [markdown]
# With just a simple implementation of Featuretools, we already have a model that outperformed the manual model.

# %%
norm_fi = plot_feature_importances(fi, 10, color = 'red')

# %% [markdown]
# Right out of the box, we see very good results from Automated Feature Engineering. Moreover, the most important feature makes intuitive sense: the total number of previous cycles is likely the most indicative indicator of when an engine will fail. We can also see that sensors 11 and 15 are very important which could indicate to the engineers they should focus on these sensors while the engine is running.

# %%
feature_matrix.to_csv('../input/feature_matrix_simple.csv')
test_feature_matrix.to_csv('../input/test_feature_matrix_simple.csv')

# %% [markdown]
# # Comparison to Manual Features
#
# We can take a look at the manual engineered features to see if there is overlap between features. We'll examine the correlations between the features and look at the top 10 most important automated features.

# %%
auto = pd.read_csv('../input/feature_matrix_simple.csv', index_col = 0)
manual = pd.read_csv('../input/simple_manual_features.csv')
auto.head()
# Out:
#            MIN(obs.operational_setting_1)  MIN(obs.sensor_measurement_10)  \
# engine_no
# 1                                  0.0000                            0.94
# 2                                  0.0000                            0.94
# 3                                  0.0002                            0.94
# 4                                  0.0004                            0.94
# 5                                  0.0008                            0.94
#
#            MIN(obs.sensor_measurement_11)  MIN(obs.sensor_measurement_12)  \
# engine_no
# 1                                   36.57                          129.63
# 2                                   36.51                          129.80
# 3                                   36.33                          130.27
# 4                                   36.54                          130.11
# 5                                   36.53                          130.15
#
# ...

# %%
mcols = []
acols = []
corrs = []

# Iterate through the features
for mcol in manual:
    for acol in auto:
        mcols.append(mcol)
        acols.append(acol)
        
        # Calculate correlations
        corrs.append(np.corrcoef(manual[mcol].values, auto[acol].values)[0, 1])

# %%
# Create dataframe of the most important features
corr_df = pd.DataFrame({'Automated Feature': acols, 'Manual Feature': mcols, 'Correlation': corrs})
top_10 = corr_df.loc[corr_df['Automated Feature'].isin(norm_fi.head(10)['feature'])]

# %%
top_10.sort_values('Correlation').tail(10)
# Out:
#                    Automated Feature             Manual Feature  Correlation
# 1017  MIN(obs.sensor_measurement_21)  sensor_measurement_21-min          1.0
# 931    MIN(obs.sensor_measurement_2)   sensor_measurement_2-min          1.0
# 71    MAX(obs.operational_setting_1)  operational_setting_1-max          1.0
# 507   MIN(obs.sensor_measurement_12)  sensor_measurement_12-min          1.0
# 1133   MIN(obs.sensor_measurement_7)   sensor_measurement_7-min          1.0
# 635   MAX(obs.sensor_measurement_14)  sensor_measurement_14-max          1.0
# 720   MAX(obs.sensor_measurement_15)  sensor_measurement_15-max          1.0
# 437   MAX(obs.sensor_measurement_11)  sensor_measurement_11-max          1.0
# 578   MAX(obs.sensor_measurement_13)  sensor_measurement_13-max          1.0
# 1253         MAX(obs.time_in_cycles)         time_in_cycles-max          1.0

# %% [markdown]
# For each of the 10 most important features from automated feature engineering, we find the exact same feature in the manual features. This raises the question of why even build the manual features in the first place? If Featuretools can do the same operation in about a tenth the time with fewer opportunities for error, it seems like the clear choice!

# %% [markdown]
# # Advanced Featuretools
#
# In the manual feature engineering notebook, we saw that performance improved slightly when we included a number of advanced operations dealing with clustering and time-series. In this notebook we'll use both the clustering and the time-series analysis. The clustering will be included by adding a column with the cluster assignment to the original dataframe and then remaking the entity. The time-series methods will be added using custom primitives.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 10)

# Need to impute the missing values
imputer = Imputer(strategy='median')
train_cluster = imputer.fit_transform(train.drop(columns = ['engine_no', 'time_in_cycles', 'index', 'time']))
test_cluster = imputer.transform(test.drop(columns = ['engine_no', 'time_in_cycles', 'index', 'time']))

# Create a new column with the cluster label
train['cluster'] = kmeans.fit_predict(train_cluster)
test['cluster'] = kmeans.predict(test_cluster)

# Redefine the entityset
es = ft.EntitySet(id = 'engines')
es = es.entity_from_dataframe(dataframe = train,
                              entity_id='obs', 
                              index = 'index',
                              time_index = 'time')

es.normalize_entity(base_entity_id='obs',
                    new_entity_id = 'engines', 
                    index = 'engine_no')

# Redefine the test entityset
test_es = ft.EntitySet(id = 'test_engines')
test_es = test_es.entity_from_dataframe(dataframe = test,
                                        entity_id='obs', 
                                        index = 'index',
                                        time_index = 'time')

test_es.normalize_entity(base_entity_id='obs',
                         new_entity_id = 'engines', 
                         index = 'engine_no')
# Out:
# Entityset: test_engines
#   Entities:
#     obs [Rows: 33991, Columns: 34]
#     engines [Rows: 259, Columns: 2]
#   Relationships:
#     obs.engine_no -> engines.engine_no

# %% [markdown]
# ## Custom Primitives
#
# The time-series methods can be included in Featuretools using [custom primitives](https://docs.featuretools.com/automated_feature_engineering/primitives.html#defining-custom-primitives). These allow us to apply any function of our creation to a dataset and mean that we can use domain knowledge with Featuretools. Moreover, Featuretools will stack these primitives like any others amplifying any work we do to make the custom primitive.
#
# Each custom primitive we make is an aggregation because it takes multiple children observations and computes a single number. (A transform primitive acts on a single column and returns as many values as there are numbers in the column).
# For each custom primitive we provide:
#
# * The function. Here we use anonymous `lambda` functions but we could define them as complete functions.
# * The input types accepted by the primitive. All of these time-series methods act on numbers so we limit the input types to `Numeric`.
# * The return type of the function. These methods return a single `Numeric` number
# * A name for the primitive
#
# Featuretools already sort entities by the `time_index` if provided with one, so the time-series operations will be applied to the data in the correct order.
#
# These parameters will change depending on the problem and the function, but we can use the same custom primitives we make here for _any dataset_. The same primitives that are useful for one problem can be _equally useful across problems_ so writing a custom primitive does not mean we spent all our time on code that can only be used once.

# %%
from tsfresh.feature_extraction.feature_calculators import (cid_ce, number_peaks, 
                                                             last_location_of_maximum, 
                                                             skewness, sample_entropy)

import featuretools.variable_types as vtypes
from featuretools.primitives import make_agg_primitive

# %%
# Define each custome primitive using lambda functinos
cid_ce_primitive = make_agg_primitive(lambda x: cid_ce(x , False),
                                      input_types = [vtypes.Numeric],
                                      return_type = vtypes.Numeric,
                                      name = 'Complexity')

number_peaks_primitive = make_agg_primitive(lambda x: number_peaks(x , 5),
                                            input_types = [vtypes.Numeric],
                                            return_type = vtypes.Numeric,
                                            name = 'NumberPeaks')

last_location_of_maximum_primititive = make_agg_primitive(lambda x: last_location_of_maximum(x),
                                                          input_types = [vtypes.Numeric],
                                                          return_type = vtypes.Numeric,
                                                          name = 'LastLocationMax')

skewness_primitive = make_agg_primitive(lambda x: skewness(x),
                                        input_types = [vtypes.Numeric],
                                        return_type = vtypes.Numeric,
                                        name = 'Skewness')

sample_entropy_primitive = make_agg_primitive(lambda x: sample_entropy(x),
                                              input_types = [vtypes.Numeric],
                                              return_type = vtypes.Numeric,
                                              name = 'Entropy')

# %% [markdown]
# Now we use the `ft.dfs` call but add in the primitives we built. We'll also add in three more aggregation primitives: `skew`, `std`, and `trend`. Ahead of time we don't know if these will be important, but there's no way to find out until we calculate them, build a model, and test the model with the features.

# %%
feature_matrix, feature_names = ft.dfs(entityset=es, target_entity='engines',
                                       agg_primitives = ['min', 'max', 'mean', 
                                                         'count', 'sum', 'last',
                                                         'skew', 'std', 'trend',
                                                         cid_ce_primitive, number_peaks_primitive, 
                                                         last_location_of_maximum_primititive,
                                                         skewness_primitive, sample_entropy_primitive],
                                       trans_primitives = ['cum_mean', 'cum_sum'],
                                       max_depth = 1, n_jobs = -1, verbose = 1,
                                       chunk_size = 100)
feature_matrix.head()
# Out:
# Built 404 features
# EntitySet scattered to workers in 1.463 seconds
# Elapsed: 01:31 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 3/3 chunks
#            MIN(obs.operational_setting_1)  MIN(obs.operational_setting_2)  \
# engine_no
# 1                                  0.0000                             0.0
# 2                                  0.0000                             0.0
# 3                                  0.0002                             0.0
# 4                                  0.0004                             0.0
# 5                                  0.0008                             0.0
#
#            MIN(obs.operational_setting_3)  MIN(obs.sensor_measurement_1)  \
# engine_no
# 1                                    60.0                          445.0
# 2                                    60.0                          445.0
# 3                                    60.0                          445.0
# ...

# %% [markdown]
# We're now up to 400+ features with just a few lines of code. The [benefits of Deep Feature Synthesis](http://www.jmaxkanter.com/static/papers/DSAA_DSM_2015.pdf) are that it is a general framework that can be repeatedly applied with only minor alterations and that it stacks primitives to create Deep Features we never would have thought of ourselves.

# %%
test_feature_matrix = ft.calculate_feature_matrix(entityset=test_es, 
                                                  features=feature_names,
                                                  n_jobs = -1, verbose = 1,
                                                  chunk_size = 100)

# Apply feature selection
feature_matrix = feature_selection(feature_matrix)
test_feature_matrix = test_feature_matrix[feature_matrix.columns]
# Out:
# EntitySet scattered to workers in 1.414 seconds
# Elapsed: 02:01 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 3/3 chunks
# Original shape:  (260, 404)
# 40 missing columns with threshold: 90.
# 41 zero variance columns.
# 214 collinear columns removed with threshold: 0.95.
# Total columns removed:  295
# Shape after feature selection: (260, 109).

# %%
feature_matrix.to_csv('../input/feature_matrix1.csv')
test_feature_matrix.to_csv('../input/test_feature_matrix1.csv')

# %% [markdown]
# ### Evaluate Custom Primitive Features
#
# We'll take the new set of features and `evaluate` them. Then we can look at the feature importances to see if any of the time-series custom primitives were of use.

# %%
preds, fi = evaluate(feature_matrix, train_labels, test_feature_matrix, test_labels)
norm_fi = plot_feature_importances(fi)
# Out:
# 5-fold CV MAPE: 45.78 with std: 4.95
# Test MAPE: 56.37.

# %% [markdown]
# Our performance on the test set has now markedly decline. It is likely that our features are causing overfitting to the training data. We'll continue with feature engineering, but it appears that a simpler set of features might be better for generalization!
#
# As with the manual feature engineering, by the most important features are derived from the time in cycles, a direct measurement of the time the engine has been running.

# %% [markdown]
# ## Increase Max Depth
#
# Another method for generating more features is to increase the maximum depth of the features. This will mean featuretools stacks more primitives on top of one another leading to a significant increase in the number of features. We can use the same exact primitives but increase the maximum depth to 2 and evaluate the results.

# %%
feature_matrix, feature_names = ft.dfs(entityset=es, target_entity='engines',
                                       agg_primitives = ['min', 'max', 'mean', 
                                                         'count', 'sum', 'last',
                                                         'skew', 'std', 'trend',
                                                         cid_ce_primitive, number_peaks_primitive, 
                                                         last_location_of_maximum_primititive,
                                                         skewness_primitive, sample_entropy_primitive],
                                       trans_primitives = ['cum_mean', 'cum_sum'],
                                       max_depth = 2, n_jobs = -1, verbose = 1,
                                       chunk_size = 100)
feature_matrix.head()
# Out:
# Built 1210 features
# EntitySet scattered to workers in 1.522 seconds
# Elapsed: 03:43 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 3/3 chunks
#            MIN(obs.operational_setting_1)  MIN(obs.operational_setting_2)  \
# engine_no
# 1                                  0.0000                             0.0
# 2                                  0.0000                             0.0
# 3                                  0.0002                             0.0
# 4                                  0.0004                             0.0
# 5                                  0.0008                             0.0
#
#            MIN(obs.operational_setting_3)  MIN(obs.sensor_measurement_1)  \
# engine_no
# 1                                    60.0                          445.0
# 2                                    60.0                          445.0
# 3                                    60.0                          445.0
# ...

# %% [markdown]
# Increasing the maximum depth tripled the number of features created. While some of these won't be useful, that will be up to the model to decide (rather than depending on our own judgement in manual feature engineering). We'll want to make the same features for the test data, perform feature selection, and then evaluate the feature matrix.

# %%
test_feature_matrix = ft.calculate_feature_matrix(entityset=test_es, 
                                                  features=feature_names,
                                                  n_jobs = -1, verbose = 1,
                                                  chunk_size = 100)

# Apply feature selection
feature_matrix = feature_selection(feature_matrix)
test_feature_matrix = test_feature_matrix[feature_matrix.columns]
# Out:
# EntitySet scattered to workers in 1.529 seconds
# Elapsed: 04:57 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 3/3 chunks
# Original shape:  (260, 1210)
# 120 missing columns with threshold: 90.
# 149 zero variance columns.
# 708 collinear columns removed with threshold: 0.95.
# Total columns removed:  977
# Shape after feature selection: (260, 233).

# %%
preds, fi = evaluate(feature_matrix, train_labels, test_feature_matrix, test_labels)
norm_fi = plot_feature_importances(fi)
# Out:
# 5-fold CV MAPE: 48.38 with std: 6.14
# Test MAPE: 59.31.

# %% [markdown]
# Increasing the maximum depth does not help our overfitting issue! The most important features now are significantly different than with the smaller feature matrix and it's possible the greater number of variables is drowning out the signal from some the of the more important variables.

# %% [markdown]
# ## Random Search
#
# The final step, just as with manual feature engineering, is to optimize the Random Forest model for our dataset. This will be done with 100 iterations of random search using 5-fold cross validation. For the features, we'll use those that performed best in cross-validation which were the simple features from a basic implementation of Featuretools.
#
# The random search is carried out by the `random_search` function in the `utils.py` script. It uses the 5-fold cross validation on the training data to determine the optimal hyperparameters.

# %%
feature_matrix = pd.read_csv('../input/feature_matrix_simple.csv')
test_feature_matrix = pd.read_csv('../input/test_feature_matrix_simple.csv')

# %%
best_model = random_search(feature_matrix, train_labels)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  2.1min finished
# Best 5-fold CV Score: 45.94 with std: 3.73.
#
# Best Hyperparameters:
# {'n_estimators': 69, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None}

# %%
from sklearn.preprocessing import Imputer

# Impute the missing values
imputer = Imputer(strategy = 'median', axis = 1)
train = imputer.fit_transform(feature_matrix.replace({np.inf:np.nan}))
test = imputer.transform(test_feature_matrix.replace({np.inf:np.nan}))

# %%
predictions = best_model.predict(test)
final_mape = 100 * np.mean(abs(predictions - test_labels) / test_labels)
print('Final Test MAPE: {:.2f}.'.format(final_mape))
# Out:
# Final Test MAPE: 49.21.

# %%
fi = pd.DataFrame({'feature': feature_matrix.columns,
                   'importance': best_model.feature_importances_})
norm_fi = plot_feature_importances(fi)

# %% [markdown]
# The 5-fold cross validation decreased with the hyperparamter tuning, but the final test score error increased. Generally, [feature engineering](https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf) will have a larger return on investment than hyperparameter tuning because a model, no matter how well optimizied, can only learn from the data we give it!

# %% [markdown]
# ## Just for Fun: Dimensionality Reduction with UMAP
#
# As an exploration of our feature matrix, we can use UMAP on the final feature matrix to see if there is a clean separation of engines in terms of the labels. We'll use UMAP to reduce the number of dimensions from 230 to 3, and then visualize the embedding colored by the label.

# %%
from umap import UMAP

# Replace the missing values
feature_matrix_ready = imputer.fit_transform(feature_matrix.replace({np.inf: np.nan}))

# UMAP embedding
umap = UMAP(n_components = 3)
train_embedding = umap.fit_transform(feature_matrix_ready)

# %%
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

# 3D plot
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111, projection='3d')

cmap = plt.get_cmap('RdYlGn_r', 10)
p = ax.scatter(train_embedding[:, 0], train_embedding[:, 1], train_embedding[:, 2], 
               c = train_labels, cmap = cmap, s = 100)
plt.title('UMAP Embedding of Final Features')
fig.colorbar(p);

# %% [markdown]
# There is some separation of data based on the labels. If we wanted, we could use these embeddings as features in a model. UMAP is a relatively new technique and it's always good to stay on top of the latest methods in data science.

# %% [markdown]
# # Conclusions
#
# Following are the complete results from the manual and automated feature engineering (this may change depending on the run because even setting random seeds did not seem to ensure stable results):
#
# | Feature Set                                                      	| Model                    	| Number of Features   (before selection) 	| Number of Features   (after selection) 	| Time to Build 	| 5-fold Train CV MAPE 	| Test MAPE 	|
# |------------------------------------------------------------------	|--------------------------	|-----------------------------------------	|----------------------------------------	|---------------	|----------------------	|-----------	|
# | Baseline Average Train Label Guess                               	| -                        	| -                                       	| -                                      	| 15 seconds    	| 158.89 (0.00)        	| 226.44    	|
# | Baseline Half Life Guess                                         	| -                        	| -                                       	| -                                      	| 30 seconds    	| 614.89 (0.00)        	| 926.51    	|
# | Simple Aggregations (No Feature Selection)                       	| Default Random Forest    	| 150                                     	| 150                                    	| 120 minutes    	| 44.56 (3.22)         	| 232.47    	|
# | Simple Aggregations                      	| Default Random Forest    	| 150                                     	| 42                                     	| 120 minutes    	| 46.62 (4.46)         	| 51.48     	|
# | Simple Aggregations +  Percent Change and Cumuluative Sum        	| Default Random Forest    	| 455                                     	| 88                                     	| 150 minutes   	| 46.13 (4.93)         	| 53.11     	|
# | Simple Aggregations + KMeans Clustering and Time-Series Analysis 	| Default Random Forest    	| 305                                     	| 88                                     	| 180 minutes   	| 45.36 (5.35)         	| 50.33     	|
# | Simple Aggregations + KMeans Clustering and Time-Series Analysis 	| Optimized Random Forest  	| 305                                     	| 88                                     	| 180 minutes   	| 45.33 (5.98)         	| 48.54     	|
# | Featuretools Basic                                               	| Default Random Forest    	| 121                                     	| 42                                     	| 15 minutes    	| 46.40 (5.77)         	| 48.95     	|
# | Featuretools with Custom Primitives  (max depth 1)               	| Default Random Forest    	| 404                                     	| 103                                    	| 30 minutes    	| 45.45 (5.27)         	| 51.56     	|
# | Featuretools with Custom Primitives (max depth 2)                	| Default Random Forest    	| 1210                                    	| 231                                    	| 35 minutes    	| 48.12 (6.41)         	| 53.55     	|
# | Featuretools basic               	| Optimized Random  Forest 	| 404                                     	| 103                                    	| 15 minutes    	| 45.94 (3.73)         	| 49.21     	|
#
#
#
# The main takeaways are as follows:
#
# 1. Featureools and manual feature engineering both significantly improve upon the baseline
# 2. Featuretools is 8x faster than even the simplest manual feature engineering
# 3. The features from automated feature engineering closely match with those from manual feature engineering.
# 4. Performance between Featuretools and manual feature engineering is very similar, with more intricate feature engineering delivering smaller returns in terms of the metrics
# 5. Feature engineering has a much greater affect on performance than hyperparameter tuning
#
# The basic Featuretools implementation performed at the same level or better than manual feature engineering and was 8x faster than even the fastest manual feature set. Adding custom primitives improved the cross validation score but decreased the score on the testing set indicating the extra features may lead to overfitting.
#
# Overall, we can conclude __Featuretools delivers the same or better performance as manual feature engineering but at a fraction of the time for development. Furthermore, the features developed by automated feature engineering align with those from manual feature engineering and can give us insight into a real-world problem.__
